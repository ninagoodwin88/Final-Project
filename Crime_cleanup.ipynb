# %%
import pandas as pd
import numpy as np
import os

# %%
#Files to load
crime_analysis = "Crimes_-_One_year_prior_to_present.csv.crdownload"
arrest_analysis = "Arrests.csv"

# %%
crime_analysis_df = pd.read_csv(crime_analysis)

# %%
arrest_analysis_df = pd.read_csv(arrest_analysis)
arrest_analysis_df
# Out:
#            CB_NO CASE NUMBER             ARREST DATE            RACE  \
# 0       18922700         NaN  06/26/2014 10:51:00 PM           BLACK
# 1       18922086         NaN  06/26/2014 12:07:00 AM           BLACK
# 2       18908465    HX290868  06/05/2014 11:58:00 AM           BLACK
# 3       18914257    HX302763  06/14/2014 04:50:00 AM           BLACK
# 4       18911035         NaN  06/09/2014 08:45:00 AM           BLACK
# ...          ...         ...                     ...             ...
# 549799  30063870    JE279841  06/26/2021 05:20:00 AM           BLACK
# 549800  30063994    JE280537  06/26/2021 07:27:00 PM           BLACK
# 549801  30063987    JE280545  06/26/2021 07:40:00 PM  WHITE HISPANIC
# 549802  30064042    JE280726  06/26/2021 11:25:00 PM           BLACK
# 549803  30064028    JE280700  06/26/2021 11:05:00 PM  WHITE HISPANIC
#
#                CHARGE 1 STATUTE  \
# 0            725 ILCS 5.0/110-3
# 1          625 ILCS 5.0/6-303-A
# 2          720 ILCS 570.0/402-C
# ...

# %%
crime_analysis_drop = crime_analysis_df.drop(axis=0,columns=["BLOCK"," IUCR"," SECONDARY DESCRIPTION"," LOCATION DESCRIPTION","BEAT","FBI CD","X COORDINATE","Y COORDINATE","LATITUDE","LONGITUDE","LOCATION"])
crime_analysis_drop
# crime_analysis_df.dtypes
# crime_analysis_drop.notnull
crime_analysis_drop.count()
# Out:
# CASE#                   80024
# DATE  OF OCCURRENCE     80024
#  PRIMARY DESCRIPTION    80024
# ARREST                  80024
# DOMESTIC                80024
# WARD                    80019
# dtype: int64

# %%
crime_analysis_drop['WARD'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 80019    False
# 80020    False
# 80021    False
# 80022    False
# 80023     True
# Name: WARD, Length: 80024, dtype: bool

# %%
crime_analysis_drop.dropna()
# Out:
#           CASE#     DATE  OF OCCURRENCE  PRIMARY DESCRIPTION ARREST DOMESTIC  \
# 0      JF121694  12/07/2021 01:00:00 PM                THEFT      N        N
# 1      JF104823  12/30/2021 03:45:00 PM   DECEPTIVE PRACTICE      N        N
# 2      JE266628  06/15/2021 09:30:00 AM                THEFT      N        N
# 3      JE266536  06/15/2021 07:50:00 AM              ASSAULT      N        N
# 4      JE266663  06/15/2021 08:40:00 AM   DECEPTIVE PRACTICE      N        N
# ...         ...                     ...                  ...    ...      ...
# 80018  JE215759  04/29/2021 03:10:00 AM                THEFT      N        N
# 80019  JE186731  04/01/2021 10:55:00 PM              ASSAULT      Y        Y
# 80020  JE214152  04/29/2021 04:30:00 PM              BATTERY      Y        N
# 80021  JE186497  04/01/2021 05:25:00 PM              BATTERY      N        Y
# 80022  JE185975  04/01/2021 09:31:00 AM              ASSAULT      N        Y
#
#        WARD
# 0       4.0
# 1      37.0
# ...

# %%
crime_analysis_notnull = crime_analysis_drop['WARD'].dropna()

# %%
crime_no_na = crime_analysis_drop.dropna()
crime_no_na.count()
# Out:
# CASE#                   80019
# DATE  OF OCCURRENCE     80019
#  PRIMARY DESCRIPTION    80019
# ARREST                  80019
# DOMESTIC                80019
# WARD                    80019
# dtype: int64

# %%
crime_analysis_df.isna()
# Out:
#        CASE#  DATE  OF OCCURRENCE  BLOCK   IUCR   PRIMARY DESCRIPTION  \
# 0      False                False  False  False                 False
# 1      False                False  False  False                 False
# 2      False                False  False  False                 False
# 3      False                False  False  False                 False
# 4      False                False  False  False                 False
# ...      ...                  ...    ...    ...                   ...
# 80019  False                False  False  False                 False
# 80020  False                False  False  False                 False
# 80021  False                False  False  False                 False
# 80022  False                False  False  False                 False
# 80023  False                False  False  False                 False
#
#         SECONDARY DESCRIPTION   LOCATION DESCRIPTION  ARREST  DOMESTIC   BEAT  \
# ...

# %%
# Drop the NaNs.
crime_analysis_df.dropna()
# Out:
#           CASE#     DATE  OF OCCURRENCE                  BLOCK  IUCR  \
# 2      JE266628  06/15/2021 09:30:00 AM     080XX S DREXEL AVE  0820
# 3      JE266536  06/15/2021 07:50:00 AM     042XX W MADISON ST  0560
# 5      JE267466  06/15/2021 09:01:00 PM     007XX S KEDZIE AVE  051B
# 6      JE266473  06/15/2021 07:47:00 AM      062XX S MORGAN ST  0110
# 7      JE267222  06/15/2021 01:55:00 AM    015XX S KENNETH AVE  4386
# ...         ...                     ...                    ...   ...
# 80017  JE216276  04/29/2021 03:00:00 PM      027XX N WAYNE AVE  0620
# 80019  JE186731  04/01/2021 10:55:00 PM        014XX W 50TH ST  0560
# 80020  JE214152  04/29/2021 04:30:00 PM   007XX W ROOSEVELT RD  0460
# 80021  JE186497  04/01/2021 05:25:00 PM  061XX S MAPLEWOOD AVE  0486
# 80022  JE185975  04/01/2021 09:31:00 AM  063XX S EGGLESTON AVE  0520
#
#        PRIMARY DESCRIPTION                    SECONDARY DESCRIPTION  \
# 2                    THEFT                           $500 AND UNDER
# ...

# %%
# crime_analysis_df.drop_duplicates()
# Out:
#           CASE#     DATE  OF OCCURRENCE                   BLOCK  IUCR  \
# 0      JF121694  12/07/2021 01:00:00 PM  052XX S BLACKSTONE AVE  0820
# 1      JF104823  12/30/2021 03:45:00 PM      017XX N CICERO AVE  1206
# 2      JE266628  06/15/2021 09:30:00 AM      080XX S DREXEL AVE  0820
# 3      JE266536  06/15/2021 07:50:00 AM      042XX W MADISON ST  0560
# 4      JE266663  06/15/2021 08:40:00 AM    044XX N ARTESIAN AVE  1153
# ...         ...                     ...                     ...   ...
# 80019  JE186731  04/01/2021 10:55:00 PM         014XX W 50TH ST  0560
# 80020  JE214152  04/29/2021 04:30:00 PM    007XX W ROOSEVELT RD  0460
# 80021  JE186497  04/01/2021 05:25:00 PM   061XX S MAPLEWOOD AVE  0486
# 80022  JE185975  04/01/2021 09:31:00 AM   063XX S EGGLESTON AVE  0520
# 80023  JE274089  06/21/2021 11:16:00 AM     046XX W HARRISON ST  0486
#
#        PRIMARY DESCRIPTION                    SECONDARY DESCRIPTION  \
# ...

# %%
crime_analysis_df['LOCATION'].nunique()
# Out:
# 52266

# %%
crime_analysis_df.count()
# Out:
# CASE#                     80024
# DATE  OF OCCURRENCE       80024
# BLOCK                     80024
#  IUCR                     80024
#  PRIMARY DESCRIPTION      80024
#  SECONDARY DESCRIPTION    80024
#  LOCATION DESCRIPTION     79702
# ARREST                    80024
# DOMESTIC                  80024
# BEAT                      80024
# WARD                      80019
# FBI CD                    80023
# X COORDINATE              78629
# Y COORDINATE              78629
# LATITUDE                  78629
# LONGITUDE                 78629
# LOCATION                  78629
# dtype: int64

# %%
# os.makedirs('folder/subfolder', exist_ok=True)  
crime_no_na.to_csv('folder/subfolder/out.csv')

# %%
reclean_crime = crime_no_na.drop_duplicates
reclean_crime.to_csv("folder/subfolder/reclean_crime.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-0bd2fff67a60> in <module>
#       1 reclean_crime = crime_no_na.drop_duplicates
# ----> 2 reclean_crime.to_csv("folder/subfolder/reclean_crime.csv")
#
# AttributeError: 'function' object has no attribute 'to_csv'

# %%
arrest_analysis_df.dtypes
# Out:
# CB_NO                    int64
# CASE NUMBER             object
# ARREST DATE             object
# RACE                    object
# CHARGE 1 STATUTE        object
# CHARGE 1 DESCRIPTION    object
# CHARGE 1 TYPE           object
# CHARGE 1 CLASS          object
# CHARGE 2 STATUTE        object
# CHARGE 2 DESCRIPTION    object
# CHARGE 2 TYPE           object
# CHARGE 2 CLASS          object
# CHARGE 3 STATUTE        object
# CHARGE 3 DESCRIPTION    object
# CHARGE 3 TYPE           object
# CHARGE 3 CLASS          object
# CHARGE 4 STATUTE        object
# CHARGE 4 DESCRIPTION    object
# CHARGE 4 TYPE           object
# CHARGE 4 CLASS          object
# CHARGES STATUTE         object
# CHARGES DESCRIPTION     object
# CHARGES TYPE            object
# CHARGES CLASS           object
# dtype: object

# %%
arrest_analysis_drop = arrest_analysis_df.drop(axis=0, columns=["CB_NO","ARREST DATE","CHARGE 1 STATUTE","CHARGE 1 DESCRIPTION",\
    "CHARGE 1 CLASS","CHARGE 2 STATUTE","CHARGE 2 DESCRIPTION","CHARGE 2 TYPE","CHARGE 2 CLASS","CHARGE 3 STATUTE","CHARGE 3 DESCRIPTION","CHARGE 3 TYPE",\
       "CHARGE 3 CLASS","CHARGE 4 STATUTE","CHARGE 4 DESCRIPTION","CHARGE 4 TYPE","CHARGE 4 CLASS","CHARGES STATUTE","CHARGES DESCRIPTION","CHARGES TYPE","CHARGES CLASS"])
arrest_analysis_drop.count()
# Out:
# CASE NUMBER      332404
# RACE             549804
# CHARGE 1 TYPE    430883
# dtype: int64

# %%
arrest_analysis_clean = arrest_analysis_drop.dropna()

# %%
arrest_analysis_clean.count()
# Out:
# CASE NUMBER      316163
# RACE             316163
# CHARGE 1 TYPE    316163
# dtype: int64

# %%
arrest_analysis_clean.to_csv('folder/subfolder/arrest_analysis_clean.csv')

# %%
arrest_clean_drop = arrest_analysis_clean.drop_duplicates()
arrest_clean_drop
arrest_analysis_drop.to_csv('folder/subfolder/arrest_analysis_drop.csv')

# %%
arrest_analysis_drop.count()
# Out:
# CASE NUMBER      332404
# RACE             549804
# CHARGE 1 TYPE    430883
# dtype: int64

# %%
arrest_analysis_reclean = arrest_analysis_drop.dropna()

# %%
arrest_analysis_reclean.count()
# Out:
# CASE NUMBER      316163
# RACE             316163
# CHARGE 1 TYPE    316163
# dtype: int64

# %%
arrest_analysis_reclean.to_csv('folder/subfolder/arrest_analysis_reclean.csv')

# %%
crime_analysis_lat_long = crime_analysis_df.drop(axis=0,columns=["BLOCK"," IUCR"," SECONDARY DESCRIPTION"," LOCATION DESCRIPTION","BEAT","FBI CD",\
    "X COORDINATE","Y COORDINATE","LOCATION"])
crime_analysis_lat_long    
clean_crime_lat_long = crime_analysis_lat_long.dropna()
# Out:
#           CASE#     DATE  OF OCCURRENCE  PRIMARY DESCRIPTION ARREST DOMESTIC  \
# 0      JF121694  12/07/2021 01:00:00 PM                THEFT      N        N
# 1      JF104823  12/30/2021 03:45:00 PM   DECEPTIVE PRACTICE      N        N
# 2      JE266628  06/15/2021 09:30:00 AM                THEFT      N        N
# 3      JE266536  06/15/2021 07:50:00 AM              ASSAULT      N        N
# 4      JE266663  06/15/2021 08:40:00 AM   DECEPTIVE PRACTICE      N        N
# ...         ...                     ...                  ...    ...      ...
# 80019  JE186731  04/01/2021 10:55:00 PM              ASSAULT      Y        Y
# 80020  JE214152  04/29/2021 04:30:00 PM              BATTERY      Y        N
# 80021  JE186497  04/01/2021 05:25:00 PM              BATTERY      N        Y
# 80022  JE185975  04/01/2021 09:31:00 AM              ASSAULT      N        Y
# 80023  JE274089  06/21/2021 11:16:00 AM              BATTERY      N        Y
#
#        WARD   LATITUDE  LONGITUDE
# ...

# %%
clean_crime_lat_long = crime_analysis_lat_long.dropna()
clean_crime_lat_long
# Out:
#           CASE#     DATE  OF OCCURRENCE  PRIMARY DESCRIPTION ARREST DOMESTIC  \
# 2      JE266628  06/15/2021 09:30:00 AM                THEFT      N        N
# 3      JE266536  06/15/2021 07:50:00 AM              ASSAULT      N        N
# 5      JE267466  06/15/2021 09:01:00 PM              ASSAULT      Y        N
# 6      JE266473  06/15/2021 07:47:00 AM             HOMICIDE      N        N
# 7      JE267222  06/15/2021 01:55:00 AM        OTHER OFFENSE      N        Y
# ...         ...                     ...                  ...    ...      ...
# 80017  JE216276  04/29/2021 03:00:00 PM             BURGLARY      N        N
# 80019  JE186731  04/01/2021 10:55:00 PM              ASSAULT      Y        Y
# 80020  JE214152  04/29/2021 04:30:00 PM              BATTERY      Y        N
# 80021  JE186497  04/01/2021 05:25:00 PM              BATTERY      N        Y
# 80022  JE185975  04/01/2021 09:31:00 AM              ASSAULT      N        Y
#
#        WARD   LATITUDE  LONGITUDE
# ...

# %%
clean_crime_lat_long.count()
# Out:
# CASE#                   78625
# DATE  OF OCCURRENCE     78625
#  PRIMARY DESCRIPTION    78625
# ARREST                  78625
# DOMESTIC                78625
# WARD                    78625
# LATITUDE                78625
# LONGITUDE               78625
# dtype: int64

# %%
crime_lat_long = clean_crime_lat_long.drop_duplicates

# %%
crime_lat_long.to_csv('folder/subfolder/crime_lat_long.csv')

# %%
crime_lat_long
# Out:
# <bound method DataFrame.drop_duplicates of           CASE#     DATE  OF OCCURRENCE  PRIMARY DESCRIPTION ARREST DOMESTIC  \
# 2      JE266628  06/15/2021 09:30:00 AM                THEFT      N        N
# 3      JE266536  06/15/2021 07:50:00 AM              ASSAULT      N        N
# 5      JE267466  06/15/2021 09:01:00 PM              ASSAULT      Y        N
# 6      JE266473  06/15/2021 07:47:00 AM             HOMICIDE      N        N
# 7      JE267222  06/15/2021 01:55:00 AM        OTHER OFFENSE      N        Y
# ...         ...                     ...                  ...    ...      ...
# 80017  JE216276  04/29/2021 03:00:00 PM             BURGLARY      N        N
# 80019  JE186731  04/01/2021 10:55:00 PM              ASSAULT      Y        Y
# 80020  JE214152  04/29/2021 04:30:00 PM              BATTERY      Y        N
# 80021  JE186497  04/01/2021 05:25:00 PM              BATTERY      N        Y
# 80022  JE185975  04/01/2021 09:31:00 AM              ASSAULT      N        Y
#
# ...
